# %% [markdown]
# ### There are two ways to download data from Kaggle (works for both - numerical and images)
# * For both you have to sign-up and log-in.
# 1. Download .zip
# 2. Use Kaggle API

# %% [markdown]
# ### There are two ML projects where you can draw inspiration
# * [Image Classification](https://github.com/Code-Institute-Org/Malaria-walkthrough-ML)
# * [Numerical](https://github.com/Code-Institute-Solutions/churnometer.git)
#
# *Feel free to reuse code snippets from these projects but do not forget to provide a reference. Also, ignore the part where Streamlit app was built. You can try it with your model, but this is beyond the scope of our module.*
#
# For our CW Projects, these two examples are particularly useful for:
# * Importing a dataset
# * Saving and reusing a trained model
